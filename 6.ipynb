# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import yahoo_fin.stock_info as si
# Out:
# Warning - Certain functionality
#              requires requests_html, which is not installed.
#
#              Install using:
#              pip install requests_html
#
#              After installation, you may have to restart your Python session.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
hd = si.get_data("AAPL")
hd.to_csv('AAPL.csv')
df = pd.read_csv('AAPL.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10005 entries, 0 to 10004
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10005 non-null  object
#  1   open        10004 non-null  float64
#  2   high        10004 non-null  float64
#  3   low         10004 non-null  float64
#  4   close       10004 non-null  float64
#  5   adjclose    10004 non-null  float64
#  6   volume      10004 non-null  float64
#  7   ticker      10005 non-null  object
# dtypes: float64(6), object(2)
# memory usage: 625.4+ KB

# %%
df.describe()
# Out:
#                open          high           low         close      adjclose  \
# count  10004.000000  10004.000000  10004.000000  10004.000000  10004.000000
# mean      35.549781     35.920315     35.186792     35.569717     33.404343
# std       65.668432     66.381410     65.034372     65.757427     64.086657
# min        0.198661      0.198661      0.196429      0.196429      0.154939
# 25%        1.080357      1.099978      1.055536      1.080357      0.919068
# 50%        1.750000      1.781696      1.716875      1.750000      1.473300
# 75%       38.745715     39.080715     38.332144     38.694999     33.437867
# max      464.250000    464.350006    455.970001    460.040009    460.040009
#
#              volume
# count  1.000400e+04
# mean   8.536791e+07
# std    8.570086e+07
# min    3.472000e+05
# 25%    3.288218e+07
# 50%    5.716970e+07
# 75%    1.063741e+08
# max    1.855410e+09

# %%
hd = si.get_data("NFLX")
hd.to_csv('NFLX.csv')
df1 = pd.read_csv('NFLX.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4591 entries, 0 to 4590
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4591 non-null   object
#  1   open        4591 non-null   float64
#  2   high        4591 non-null   float64
#  3   low         4591 non-null   float64
#  4   close       4591 non-null   float64
#  5   adjclose    4591 non-null   float64
#  6   volume      4591 non-null   int64
#  7   ticker      4591 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 287.1+ KB

# %%
df1.describe()
# Out:
#               open         high          low        close     adjclose  \
# count  4591.000000  4591.000000  4591.000000  4591.000000  4591.000000
# mean     78.930278    80.193267    77.622376    78.966083    78.966083
# std     119.799490   121.707597   117.789075   119.845776   119.845776
# min       0.377857     0.410714     0.346429     0.372857     0.372857
# 25%       3.782143     3.861428     3.694286     3.788571     3.788571
# 50%      15.492857    15.807143    15.078571    15.447143    15.447143
# 75%      98.060001    99.915001    96.910000    98.099998    98.099998
# max     567.979980   575.369995   520.960022   548.729980   548.729980
#
#              volume
# count  4.591000e+03
# mean   1.757641e+07
# std    1.969960e+07
# min    2.856000e+05
# 25%    6.888000e+06
# 50%    1.152480e+07
# 75%    2.110745e+07
# max    3.234140e+08

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 5, 1)
plt.title('open')
sns.violinplot(y='open',data=df,palette='summer',linewidth=3)
plt.subplot(1, 5, 2)
plt.title('high')
sns.violinplot(y='high',data=df,palette='Wistia_r',linewidth=3)
plt.subplot(1, 5, 3)
plt.title('low')
sns.violinplot(y='low',data=df,palette='spring',linewidth=3)
plt.subplot(1, 5, 4)
plt.title('adjclose')
sns.violinplot(y='adjclose',data=df,palette='spring',linewidth=3)
plt.subplot(1, 5, 5)
plt.title('volume')
sns.violinplot(y='volume',data=df,palette='spring',linewidth=3)
plt.show()
# Out:
# Text(0.5, 1.0, 'open')
# Text(0.5, 1.0, 'high')
# Text(0.5, 1.0, 'low')
# Text(0.5, 1.0, 'adjclose')
# Text(0.5, 1.0, 'volume')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 5, 1)
plt.title('open')
sns.violinplot(y='open',data=df1,palette='summer',linewidth=3)
plt.subplot(1, 5, 2)
plt.title('high')
sns.violinplot(y='high',data=df1,palette='Wistia_r',linewidth=3)
plt.subplot(1, 5, 3)
plt.title('low')
sns.violinplot(y='low',data=df1,palette='spring',linewidth=3)
plt.subplot(1, 5, 4)
plt.title('adjclose')
sns.violinplot(y='adjclose',data=df1,palette='spring',linewidth=3)
plt.subplot(1, 5, 5)
plt.title('volume')
sns.violinplot(y='volume',data=df1,palette='spring',linewidth=3)
plt.show()
# Out:
# Text(0.5, 1.0, 'open')
# Text(0.5, 1.0, 'high')
# Text(0.5, 1.0, 'low')
# Text(0.5, 1.0, 'adjclose')
# Text(0.5, 1.0, 'volume')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 5, 1)
plt.title('open')
sns.violinplot(y='open',data=df2,palette='summer',linewidth=3)
plt.subplot(1, 5, 2)
plt.title('high')
sns.violinplot(y='high',data=df2,palette='Wistia_r',linewidth=3)
plt.subplot(1, 5, 3)
plt.title('low')
sns.violinplot(y='low',data=df2,palette='spring',linewidth=3)
plt.subplot(1, 5, 4)
plt.title('adjclose')
sns.violinplot(y='adjclose',data=df2,palette='spring',linewidth=3)
plt.subplot(1, 5, 5)
plt.title('volume')
sns.violinplot(y='volume',data=df2,palette='spring',linewidth=3)
plt.show()
# Out:
# Text(0.5, 1.0, 'open')
# Text(0.5, 1.0, 'high')
# Text(0.5, 1.0, 'low')
# Text(0.5, 1.0, 'adjclose')
# Text(0.5, 1.0, 'volume')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 5, 1)
plt.title('open')
sns.violinplot(y='open',data=df3,palette='summer',linewidth=3)
plt.subplot(1, 5, 2)
plt.title('high')
sns.violinplot(y='high',data=df3,palette='Wistia_r',linewidth=3)
plt.subplot(1, 5, 3)
plt.title('low')
sns.violinplot(y='low',data=df3,palette='spring',linewidth=3)
plt.subplot(1, 5, 4)
plt.title('adjclose')
sns.violinplot(y='adjclose',data=df3,palette='spring',linewidth=3)
plt.subplot(1, 5, 5)
plt.title('volume')
sns.violinplot(y='volume',data=df3,palette='spring',linewidth=3)
plt.show()
# Out:
# Text(0.5, 1.0, 'open')
# Text(0.5, 1.0, 'high')
# Text(0.5, 1.0, 'low')
# Text(0.5, 1.0, 'adjclose')
# Text(0.5, 1.0, 'volume')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 5, 1)
plt.title('open')
sns.violinplot(y='open',data=df4,palette='summer',linewidth=3)
plt.subplot(1, 5, 2)
plt.title('high')
sns.violinplot(y='high',data=df4,palette='Wistia_r',linewidth=3)
plt.subplot(1, 5, 3)
plt.title('low')
sns.violinplot(y='low',data=df4,palette='spring',linewidth=3)
plt.subplot(1, 5, 4)
plt.title('adjclose')
sns.violinplot(y='adjclose',data=df4,palette='spring',linewidth=3)
plt.subplot(1, 5, 5)
plt.title('volume')
sns.violinplot(y='volume',data=df4,palette='spring',linewidth=3)
plt.show()
# Out:
# Text(0.5, 1.0, 'open')
# Text(0.5, 1.0, 'high')
# Text(0.5, 1.0, 'low')
# Text(0.5, 1.0, 'adjclose')
# Text(0.5, 1.0, 'volume')

# %%
hd = si.get_data("GOOG")
hd.to_csv('GOOG.csv')
df2 = pd.read_csv('GOOG.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4027 entries, 0 to 4026
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4027 non-null   object
#  1   open        4027 non-null   float64
#  2   high        4027 non-null   float64
#  3   low         4027 non-null   float64
#  4   close       4027 non-null   float64
#  5   adjclose    4027 non-null   float64
#  6   volume      4027 non-null   int64
#  7   ticker      4027 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 251.8+ KB

# %%
df2.describe()
# Out:
#               open         high          low        close     adjclose  \
# count  4027.000000  4027.000000  4027.000000  4027.000000  4027.000000
# mean    524.747943   529.697949   519.653159   524.837672   524.837672
# std     375.251645   378.799139   372.033848   375.679605   375.679605
# min      49.409801    50.680038    47.800831    49.818268    49.818268
# 25%     239.579491   242.022835   237.621834   239.661690   239.661690
# 50%     338.730347   342.142578   335.497467   339.089020   339.089020
# 75%     767.005005   770.690002   759.070007   765.175018   765.175018
# max    1586.989990  1586.989990  1554.280029  1568.489990  1568.489990
#
#              volume
# count  4.027000e+03
# mean   6.888706e+06
# std    7.982725e+06
# min    7.900000e+03
# 25%    1.709300e+06
# 50%    4.194300e+06
# 75%    8.777300e+06
# max    8.254150e+07

# %%
hd = si.get_data("AMZN")
hd.to_csv('AMZN.csv')
df3 = pd.read_csv('AMZN.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5853 entries, 0 to 5852
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5853 non-null   object
#  1   open        5853 non-null   float64
#  2   high        5853 non-null   float64
#  3   low         5853 non-null   float64
#  4   close       5853 non-null   float64
#  5   adjclose    5853 non-null   float64
#  6   volume      5853 non-null   int64
#  7   ticker      5853 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 365.9+ KB

# %%
df3.describe()
# Out:
#               open         high          low        close     adjclose  \
# count  5853.000000  5853.000000  5853.000000  5853.000000  5853.000000
# mean    377.947201   382.217634   373.290994   377.976507   377.976507
# std     597.358822   603.680870   590.299481   597.346512   597.346512
# min       1.406250     1.447917     1.312500     1.395833     1.395833
# 25%      38.000000    38.590000    37.250000    37.950001    37.950001
# 50%      83.699997    85.059998    82.099998    83.625000    83.625000
# 75%     361.609985   365.869995   358.230011   362.570007   362.570007
# max    3251.060059  3344.290039  3165.429932  3225.000000  3225.000000
#
#              volume
# count  5.853000e+03
# mean   7.511583e+06
# std    7.278000e+06
# min    4.872000e+05
# 25%    3.681900e+06
# 50%    5.652700e+06
# 75%    8.515900e+06
# max    1.043292e+08

# %%
hd = si.get_data("IBM")
hd.to_csv('IBM.csv')
df4 = pd.read_csv('IBM.csv')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12714 entries, 0 to 12713
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12714 non-null  object
#  1   open        12714 non-null  float64
#  2   high        12714 non-null  float64
#  3   low         12714 non-null  float64
#  4   close       12714 non-null  float64
#  5   adjclose    12714 non-null  float64
#  6   volume      12714 non-null  int64
#  7   ticker      12714 non-null  object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 794.8+ KB

# %%
df4.describe()
# Out:
#                open          high           low         close      adjclose  \
# count  12714.000000  12714.000000  12714.000000  12714.000000  12714.000000
# mean      68.606072     69.246588     67.997618     68.627664     44.948504
# std       57.830892     58.286138     57.407816     57.857251     50.263396
# min        9.500000      9.828125      9.406250      9.500000      0.829208
# 25%       18.468750     18.625000     18.330469     18.457031      2.544549
# 50%       33.718750     34.093750     33.312500     33.750000     12.926501
# 75%      115.500000    116.795002    113.750000    115.397501     75.733015
# max      215.380005    215.899994    214.300003    215.800003    161.213455
#
#              volume
# count  1.271400e+04
# mean   5.545972e+06
# std    4.458475e+06
# min    0.000000e+00
# 25%    2.563175e+06
# 50%    4.763250e+06
# 75%    7.331975e+06
# max    6.944470e+07

# %%
ticker_list = ["AMZN", "GOOG", "NFLX", "IBM", "AAPL"]

# %%
for ticker in ticker_list:
    print("Historical data of",ticker)
    si.get_data(ticker)
# Out:
# Historical data of AMZN
#                    open         high          low        close     adjclose  \
# 1997-05-15     2.437500     2.500000     1.927083     1.958333     1.958333
# 1997-05-16     1.968750     1.979167     1.708333     1.729167     1.729167
# 1997-05-19     1.760417     1.770833     1.625000     1.708333     1.708333
# 1997-05-20     1.729167     1.750000     1.635417     1.635417     1.635417
# 1997-05-21     1.635417     1.645833     1.375000     1.427083     1.427083
# ...                 ...          ...          ...          ...          ...
# 2020-08-11  3113.199951  3159.219971  3073.000000  3080.669922  3080.669922
# 2020-08-12  3108.000000  3174.389893  3101.419922  3162.239990  3162.239990
# 2020-08-13  3182.989990  3217.520020  3155.000000  3161.020020  3161.020020
# 2020-08-14  3178.179932  3178.239990  3120.000000  3148.020020  3148.020020
# 2020-08-17  3173.120117  3190.050049  3158.000000  3166.750000  3166.750000
#
#               volume ticker
# ...

# %%
for ticker in ticker_list:
    print("Balance sheet of",ticker)
    si.get_balance_sheet(ticker)
# Out:
# Balance sheet of AMZN
# endDate                    2019-12-31    2018-12-31    2017-12-31  \
# Breakdown
# intangibleAssets         4.049000e+09  4.110000e+09  3.371000e+09
# capitalSurplus           3.365800e+10  2.679100e+10  2.138900e+10
# totalLiab                1.631880e+11  1.190990e+11  1.036010e+11
# totalStockholderEquity   6.206000e+10  4.354900e+10  2.770900e+10
# otherCurrentLiab         1.220200e+10  9.959000e+09  8.565000e+09
# totalAssets              2.252480e+11  1.626480e+11  1.313100e+11
# commonStock              5.000000e+06  5.000000e+06  5.000000e+06
# otherCurrentAssets       2.760000e+08  4.180000e+08  1.329000e+09
# retainedEarnings         3.122000e+10  1.962500e+10  8.636000e+09
# otherLiab                1.217100e+10  1.756300e+10  7.792000e+09
# goodWill                 1.475400e+10  1.454800e+10  1.335000e+10
# treasuryStock           -2.823000e+09 -2.872000e+09 -2.321000e+09
# otherAssets              1.009600e+10  6.370000e+09  5.085000e+09
# ...

# %%
for ticker in ticker_list:
    print("Statistics of",ticker)
    si.get_stats(ticker)
# Out:
# Statistics of AMZN
#                                          Attribute         Value
# 0                                Beta (5Y Monthly)          1.33
# 1                                 52-Week Change 3        73.34%
# 2                          S&P500 52-Week Change 3        15.36%
# 3                                   52 Week High 3       3344.29
# 4                                    52 Week Low 3       1626.03
# 5                          50-Day Moving Average 3       3063.89
# 6                         200-Day Moving Average 3       2429.31
# 7                              Avg Vol (3 month) 3         4.59M
# 8                               Avg Vol (10 day) 3         3.37M
# 9                             Shares Outstanding 5       500.89M
# 10                                           Float       425.63M
# 11                            % Held by Insiders 1        15.12%
# 12                        % Held by Institutions 1        57.69%
# ...

# %%
for ticker in ticker_list:
    print("Analysis of",ticker)
    analysts = si.get_analysts_info(ticker)
    for i in analysts:
        analysts[i]
# Out:
# Analysis of AMZN
#   Earnings Estimate  Current Qtr. (Sep 2020)  Next Qtr. (Dec 2020)  \
# 0   No. of Analysts                    39.00                 38.00
# 1     Avg. Estimate                     7.25                  8.89
# 2      Low Estimate                     4.62                  4.71
# 3     High Estimate                    12.01                 15.55
# 4      Year Ago EPS                     4.23                  6.47
#
#    Current Year (2020)  Next Year (2021)
# 0                43.00             45.00
# 1                31.64             44.27
# 2                24.64             32.55
# 3                42.92             72.34
# 4                23.01             31.64
#           Revenue Estimate Current Qtr. (Sep 2020) Next Qtr. (Dec 2020)  \
# 0          No. of Analysts                      37                   37
# 1            Avg. Estimate                  92.39B              110.89B
# 2             Low Estimate                  90.07B              104.16B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10005 entries, 0 to 10004
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10005 non-null  object
#  1   open        10004 non-null  float64
#  2   high        10004 non-null  float64
#  3   low         10004 non-null  float64
#  4   close       10004 non-null  float64
#  5   adjclose    10004 non-null  float64
#  6   volume      10004 non-null  float64
#  7   ticker      10005 non-null  object
# dtypes: float64(6), object(2)
# memory usage: 625.4+ KB

# %%
df.describe()
# Out:
#                open          high           low         close      adjclose  \
# count  10004.000000  10004.000000  10004.000000  10004.000000  10004.000000
# mean      35.549781     35.920315     35.186912     35.569899     33.404524
# std       65.668432     66.381410     65.035149     65.758593     64.087860
# min        0.198661      0.198661      0.196429      0.196429      0.154939
# 25%        1.080357      1.099978      1.055536      1.080357      0.919068
# 50%        1.750000      1.781696      1.716875      1.750000      1.473300
# 75%       38.745715     39.080715     38.332144     38.694999     33.437867
# max      464.250000    464.350006    457.170013    460.040009    460.040009
#
#              volume
# count  1.000400e+04
# mean   8.536778e+07
# std    8.570098e+07
# min    3.472000e+05
# 25%    3.288218e+07
# 50%    5.716970e+07
# 75%    1.063741e+08
# max    1.855410e+09
